# %%
import pandas as pd

# %%
df = pd.read_csv('torRapCurrentPerGame.csv')

# %%
display(df)
# Out:
#                   Player  Age   G  GS    MP   FG   FGA    FG%   3P  3PA  ...  \
# 0          Fred VanVleet   28  24  24  36.8  6.1  15.8  0.386  2.8  8.4  ...
# 1             OG Anunoby   25  26  26  36.7  7.1  14.9  0.475  1.5  4.7  ...
# 2          Pascal Siakam   28  20  20  35.6  8.7  18.2  0.475  1.4  3.9  ...
# 3         Scottie Barnes   21  27  26  33.7  6.0  13.2  0.452  1.1  3.5  ...
# 4         Gary Trent Jr.   24  25  18  31.3  5.9  13.8  0.430  2.3  6.8  ...
# 5          Chris Boucher   30  26   0  22.8  3.8   8.4  0.447  0.8  2.9  ...
# 6       Precious Achiuwa   23  12   0  20.4  3.0   7.7  0.391  0.4  2.3  ...
# 7   Juancho HernangĆ³mez   27  19   5  18.9  1.8   3.7  0.500  0.6  2.0  ...
# 8        Otto Porter Jr.   29   8   2  18.3  1.9   3.8  0.500  0.8  2.1  ...
# 9         Thaddeus Young   34  27   9  17.2  2.3   4.2  0.540  0.1  0.7  ...
# 10      Christian Koloko   22  30  17  16.8  1.4   3.1  0.446  0.0  0.2  ...
# ...

# %%
df.at[7, 'Player']='Juancho Hernangomez'

# %%
display(df)
# Out:
#                  Player  Age   G  GS    MP   FG   FGA    FG%   3P  3PA  ...  \
# 0         Fred VanVleet   28  24  24  36.8  6.1  15.8  0.386  2.8  8.4  ...
# 1            OG Anunoby   25  26  26  36.7  7.1  14.9  0.475  1.5  4.7  ...
# 2         Pascal Siakam   28  20  20  35.6  8.7  18.2  0.475  1.4  3.9  ...
# 3        Scottie Barnes   21  27  26  33.7  6.0  13.2  0.452  1.1  3.5  ...
# 4        Gary Trent Jr.   24  25  18  31.3  5.9  13.8  0.430  2.3  6.8  ...
# 5         Chris Boucher   30  26   0  22.8  3.8   8.4  0.447  0.8  2.9  ...
# 6      Precious Achiuwa   23  12   0  20.4  3.0   7.7  0.391  0.4  2.3  ...
# 7   Juancho Hernangomez   27  19   5  18.9  1.8   3.7  0.500  0.6  2.0  ...
# 8       Otto Porter Jr.   29   8   2  18.3  1.9   3.8  0.500  0.8  2.1  ...
# 9        Thaddeus Young   34  27   9  17.2  2.3   4.2  0.540  0.1  0.7  ...
# 10     Christian Koloko   22  30  17  16.8  1.4   3.1  0.446  0.0  0.2  ...
# ...

# %%
#change all % to P to indicate percentage


df.columns = df.columns.str.replace('%', 'P')
display(df)
# Out:
#                  Player  Age   G  GS    MP   FG   FGA    FGP   3P  3PA  ...  \
# 0         Fred VanVleet   28  24  24  36.8  6.1  15.8  0.386  2.8  8.4  ...
# 1            OG Anunoby   25  26  26  36.7  7.1  14.9  0.475  1.5  4.7  ...
# 2         Pascal Siakam   28  20  20  35.6  8.7  18.2  0.475  1.4  3.9  ...
# 3        Scottie Barnes   21  27  26  33.7  6.0  13.2  0.452  1.1  3.5  ...
# 4        Gary Trent Jr.   24  25  18  31.3  5.9  13.8  0.430  2.3  6.8  ...
# 5         Chris Boucher   30  26   0  22.8  3.8   8.4  0.447  0.8  2.9  ...
# 6      Precious Achiuwa   23  12   0  20.4  3.0   7.7  0.391  0.4  2.3  ...
# 7   Juancho Hernangomez   27  19   5  18.9  1.8   3.7  0.500  0.6  2.0  ...
# 8       Otto Porter Jr.   29   8   2  18.3  1.9   3.8  0.500  0.8  2.1  ...
# 9        Thaddeus Young   34  27   9  17.2  2.3   4.2  0.540  0.1  0.7  ...
# 10     Christian Koloko   22  30  17  16.8  1.4   3.1  0.446  0.0  0.2  ...
# ...

# %%
#get rid of players with no real impact on the game(anything under 4 games played indicates garbage time)
#If this season was done, I would also correct for if an impactful player only played under a certain amount of games due to injury
#This would be done by ruling out anyone below 7 MPG.
df2=df[df.G >= 4]
display(df2)
df_out = df2
df_out_to_csv('torRapCurrentPerGame.csv', index = false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22396/2726975034.py in <module>
#       2 #If this season was done, I would also correct for if an impactful player only played under a certain amount of games due to injury
#       3 #This would be done by ruling out anyone below 7 MPG.
# ----> 4 df2=df[df.G >= 4]
#       5 display(df2)
#       6 df_out = df2
#
# NameError: name 'df' is not defined

# %%
#df2['FGP'].round(decimals = 2)
#df2.round(decimals = 2)
#display(df2.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22396/2734891649.py in <module>
#       2 #df2.round(decimals = 2)
#       3 #display(df2.dtypes)
# ----> 4 df_out = df2
#       5 df_out_to_csv('torRapCurrentPerGame.csv', index = false)
#
# NameError: name 'df2' is not defined
